# %% [markdown]
# This notebook is part of the $\omega radlib$ documentation: https://docs.wradlib.org.
#
# Copyright (c) $\omega radlib$ developers.
# Distributed under the MIT License. See LICENSE.txt for more info.

# %% [markdown]
# # Load ODIM_H5 Volume data from German Weather Service
#
# In this example, we obtain and read the latest available volumetric radar data from German Weather Service available at [opendata.dwd.de](https://opendata.dwd.de). Finally we do some plotting.
#
# This retrieves the 10 sweeps (moments DBZH and VRADH) of the DWD volume scan of a distinct radar. This amounts to 20 data files which are combined into one volumetric Cf/Radial2 like xarray powered structure.
#
# Exports to singel file Odim_H5 and Cf/Radial2 format are shown at the end of this tutorial.

# %%
import wradlib as wrl
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as pl
import numpy as np
import xarray as xr
try:
    get_ipython().magic("matplotlib inline")
except:
    pl.ion()
from wradlib.io.xarray import CfRadial, OdimH5

# %%
import urllib
import os
import io
import glob

# %% [markdown]
# ## Download Current Filelist from server
#
# Import it into pandas DataFrame, export to list and sort it descending in time.

# %% [markdown]
# ### Helper Class to parse response

# %%
from html.parser import HTMLParser

class DWDHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        if tag != 'a':
            return
        self.links.append(attrs[0][1])

parser = DWDHTMLParser()

# %%
radar = 'ESS'
DBZH = 'sweep_vol_z'
VRADH = 'sweep_vol_v'

opendata_url1 = (f"https://opendata.dwd.de/weather/radar/sites/{DBZH}/{radar.lower()}/hdf5/")
with urllib.request.urlopen(opendata_url1) as url_request:
    response = url_request.read().decode("utf-8")

parser.links = []
parser.feed(response)
filelist1 = parser.links[1:]

filelist1.sort(key=lambda x: x.split('-')[2])
filelist1.reverse()

opendata_url2 = (f"https://opendata.dwd.de/weather/radar/sites/{VRADH}/{radar.lower()}/hdf5/")
with urllib.request.urlopen(opendata_url2) as url_request:
    response = url_request.read().decode("utf-8")

parser.links = []
parser.feed(response)
filelist2 = parser.links[1:]

filelist2.sort(key=lambda x: x.split('-')[2])
filelist2.reverse()

# %%
for f in filelist1[:10]:
    print(f)
# Out:
# ras07-vol5minng01_sweeph5onem_dbzh_09-2019091315190300-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_dbzh_08-2019091315184900-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_dbzh_07-2019091315183600-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_dbzh_06-2019091315182200-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_dbzh_05-2019091315180100-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_dbzh_04-2019091315173000-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_dbzh_03-2019091315170700-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_dbzh_02-2019091315164400-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_dbzh_01-2019091315162100-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_dbzh_00-2019091315155800-ess-10410-hd5

# %%
for f in filelist2[:10]:
    print(f)
# Out:
# ras07-vol5minng01_sweeph5onem_vradh_09-2019091315190300-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_vradh_08-2019091315184900-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_vradh_07-2019091315183600-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_vradh_06-2019091315182200-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_vradh_05-2019091315180100-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_vradh_04-2019091315173000-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_vradh_03-2019091315170700-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_vradh_02-2019091315164400-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_vradh_01-2019091315162100-ess-10410-hd5
# ras07-vol5minng01_sweeph5onem_vradh_00-2019091315155800-ess-10410-hd5

# %% [markdown]
# ## Clean up local folder

# %%
flist = glob.glob('ras07*')
for f in flist:
    os.remove(f)

# %% [markdown]
# ## Download latest volume to current directory

# %%
for f in filelist1[:10]:
    urllib.request.urlretrieve(os.path.join(opendata_url1, f), f)
    
for f in filelist2[:10]:
    urllib.request.urlretrieve(os.path.join(opendata_url2, f), f)

# %% [markdown]
# ## Read the files into xarray powered structure

# %%
flist = glob.glob('ras07*')
vol = wrl.io.OdimH5(flist, dim0='azimuth', georef=True)

# %% [markdown]
# ## Inspect structure
# ### Root Group

# %%
vol.root
# Out:
# <xarray.Dataset>
# Dimensions:              (sweep: 10)
# Dimensions without coordinates: sweep
# Data variables:
#     volume_number        int64 0
#     platform_type        <U5 'fixed'
#     instrument_type      <U5 'radar'
#     primary_axis         <U6 'axis_z'
#     latitude             float64 51.41
#     longitude            float64 6.967
#     altitude             float64 185.0
#     altitude_agl         float64 nan
#     frequency            float64 nan
#     status_xml           <U4 'None'
#     time_coverage_start  <U20 '2019-09-13T15:15:35Z'
#     time_coverage_end    <U20 '2019-09-13T15:19:03Z'
#     sweep_group_name     (sweep) <U8 'sweep_1' 'sweep_2' ... 'sweep_10'
#     sweep_fixed_angle    (sweep) float64 12.0 25.0 4.499 ... 5.499 1.5 2.499
# Attributes:
#     Conventions:          Cf/Radial
#     version:              H5rad 2.2
#     title:                None
#     institution:          WMO:10410,NOD:deess
#     references:           None
#     source:               None
#     history:              None
#     comment:              im/exported using wradlib
#     instrument_name:      None
#     site_name:            name of site where data were gathered
#     scan_name:            name of scan strategy used, if applicable
#     scan_id:              scan strategy id, if applicable. assumed 0 if missing
#     platform_is_mobile:   "true" or "false", assumed "false" if missing
#     ray_times_increase:   "true" or "false", assumed "true" if missing. This ...
#     field_names:          array of strings of field names present in this file.
#     time_coverage_start:  copy of time_coverage_start global variable
#     time_coverage_end:    copy of time_coverage_end global variable
#     simulated data:       "true" or "false", assumed "false" if missing. data...
#     instrument:           WMO:10410,NOD:deess

# %%
vol.root.sweep_fixed_angle
# Out:
# <xarray.DataArray 'sweep_fixed_angle' (sweep: 10)>
# array([12.002563, 24.99939 ,  4.498901,  7.998047, 17.001343,  3.499146,
#         0.499878,  5.498657,  1.499634,  2.49939 ])
# Dimensions without coordinates: sweep

# %% [markdown]
# ### Sweep Groups

# %%
list(vol)
# Out:
# ['sweep_1',
#  'sweep_2',
#  'sweep_3',
#  'sweep_4',
#  'sweep_5',
#  'sweep_6',
#  'sweep_7',
#  'sweep_8',
#  'sweep_9',
#  'sweep_10']

# %%
vol['sweep_1']
# Out:
# <xarray.Dataset>
# Dimensions:       (azimuth: 360, range: 60)
# Coordinates:
#   * azimuth       (azimuth) float64 0.5109 1.527 2.521 ... 357.5 358.5 359.5
#     elevation     (azimuth) float64 12.01 12.01 12.01 ... 12.01 12.01 12.01
#   * range         (range) float32 500.0 1500.0 2500.0 ... 58500.0 59500.0
#     sweep_mode    <U20 'azimuth_surveillance'
#     longitude     float64 6.967
#     latitude      float64 51.41
#     altitude      float64 185.0
#     x             (azimuth, range) float64 4.36 13.08 21.8 ... -495.7 -504.2
#     y             (azimuth, range) float64 489.0 1.467e+03 ... 5.811e+04
#     z             (azimuth, range) float64 289.0 497.0 ... 1.255e+04 1.276e+04
#     gr            (azimuth, range) float64 489.0 1.467e+03 ... 5.811e+04
#     rays          (azimuth, range) float64 0.5109 0.5109 0.5109 ... 359.5 359.5
#     bins          (azimuth, range) float32 500.0 1500.0 ... 58500.0 59500.0
#     time          (azimuth) datetime64[ns] 2019-09-13T15:18:30.914000128 ... 2019-09-13T15:18:30.880499968
# Data variables:
#     VRADH         (azimuth, range) float32 ...
#     fixed_angle   float64 12.0
#     follow_mode   <U4 'none'
#     prt_mode      <U5 'fixed'
#     sweep_number  int64 0
#     DBZH          (azimuth, range) float32 ...

# %% [markdown]
# ## plot sweeps
# ### DBZH

# %%
fig = pl.figure(figsize=(20, 30))
import matplotlib.gridspec as gridspec
gs = gridspec.GridSpec(4, 3, wspace=0.4, hspace=0.4)
for i, swp in enumerate(vol.values()):
    swp.DBZH.wradlib.plot(ax=gs[i], fig=fig)
    ax = pl.gca()
    ax.set_title(vol.root.sweep_fixed_angle[i])

# %% [markdown]
# ### VRADH

# %%
fig = pl.figure(figsize=(20, 30))
import matplotlib.gridspec as gridspec
gs = gridspec.GridSpec(4, 3, wspace=0.4, hspace=0.4)
for i, swp in enumerate(vol.values()):
    swp.VRADH.wradlib.plot(ax=gs[i], fig=fig)
    ax = pl.gca()
    ax.set_title(vol.root.sweep_fixed_angle[i])

# %% [markdown]
# ### Plot single sweep using cartopy

# %%
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature

map_trans = ccrs.AzimuthalEquidistant(central_latitude=vol['sweep_10'].latitude.values, 
                                      central_longitude=vol['sweep_10'].longitude.values)

# %%
map_proj = ccrs.AzimuthalEquidistant(central_latitude=vol['sweep_10'].latitude.values, 
                                      central_longitude=vol['sweep_10'].longitude.values)
pm = vol['sweep_10'].DBZH.wradlib.plot_ppi(proj=map_proj)
ax = pl.gca()
ax.gridlines(crs=map_proj)
print(ax)
# Out:
# < GeoAxes: <cartopy.crs.AzimuthalEquidistant object at 0x7feb4886a258> >

# %%
map_proj = ccrs.Mercator(central_longitude=vol['sweep_10'].longitude.values)
fig = pl.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection=map_proj)
pm = vol['sweep_10'].DBZH.wradlib.plot_ppi(ax=ax)
ax.gridlines(draw_labels=True)

# %%
fig = pl.figure(figsize=(10, 8))
proj=ccrs.AzimuthalEquidistant(central_latitude=vol['sweep_10'].latitude.values, 
                               central_longitude=vol['sweep_10'].longitude.values)
ax = fig.add_subplot(111, projection=proj)
pm = vol['sweep_10'].DBZH.wradlib.plot_ppi(ax=ax)
ax.gridlines()

# %% [markdown]
# ### Inspect radar moments
#
# The dataarrays can be accessed by key or by attribute. Each dataarray has the datasets dimensions and coordinates of it's parent dataset. There are attributes connected which are defined by Cf/Radial and/or ODIM_H5 standard.

# %%
vol['sweep_10'].DBZH
# Out:
# <xarray.DataArray 'DBZH' (azimuth: 360, range: 180)>
# array([[-64.00293, -64.00293, -64.00293, ..., -64.00293, -64.00293, -64.00293],
#        [-64.00293, -64.00293, -64.00293, ..., -64.00293, -64.00293, -64.00293],
#        [-64.00293, -64.00293, -64.00293, ..., -64.00293, -64.00293, -64.00293],
#        ...,
#        [-64.00293, -64.00293, -64.00293, ..., -64.00293, -64.00293, -64.00293],
#        [-64.00293, -64.00293, -64.00293, ..., -64.00293, -64.00293, -64.00293],
#        [-64.00293, -64.00293, -64.00293, ..., -64.00293, -64.00293, -64.00293]],
#       dtype=float32)
# Coordinates:
#   * azimuth     (azimuth) float64 0.5219 1.538 2.532 3.532 ... 357.5 358.5 359.5
#     elevation   (azimuth) float64 2.494 2.494 2.494 2.494 ... 2.494 2.494 2.494
#   * range       (range) float32 500.0 1500.0 2500.0 ... 178500.0 179500.0
#     sweep_mode  <U20 'azimuth_surveillance'
#     longitude   float64 6.967
#     latitude    float64 51.41
#     altitude    float64 185.0
#     x           (azimuth, range) float64 4.55 13.65 ... -1.529e+03 -1.537e+03
#     y           (azimuth, range) float64 499.5 1.498e+03 ... 1.781e+05 1.791e+05
#     z           (azimuth, range) float64 206.7 250.2 ... 9.824e+03 9.888e+03
#     gr          (azimuth, range) float64 499.5 1.499e+03 ... 1.781e+05 1.791e+05
#     rays        (azimuth, range) float64 0.5219 0.5219 0.5219 ... 359.5 359.5
#     bins        (azimuth, range) float32 500.0 1500.0 ... 178500.0 179500.0
#     time        (azimuth) datetime64[ns] 2019-09-13T15:17:02.328499712 ... 2019-09-13T15:17:02.264999936
# Attributes:
#     standard_name:  radar_equivalent_reflectivity_factor_h
#     long_name:      Equivalent reflectivity factor H
#     units:          dBZ

# %%
vol['sweep_10'].sweep_mode
# Out:
# <xarray.DataArray 'sweep_mode' ()>
# array('azimuth_surveillance', dtype='<U20')
# Coordinates:
#     sweep_mode  <U20 'azimuth_surveillance'
#     longitude   float64 6.967
#     latitude    float64 51.41
#     altitude    float64 185.0

# %%
vol.root
# Out:
# <xarray.Dataset>
# Dimensions:              (sweep: 10)
# Dimensions without coordinates: sweep
# Data variables:
#     volume_number        int64 0
#     platform_type        <U5 'fixed'
#     instrument_type      <U5 'radar'
#     primary_axis         <U6 'axis_z'
#     latitude             float64 51.41
#     longitude            float64 6.967
#     altitude             float64 185.0
#     altitude_agl         float64 nan
#     frequency            float64 nan
#     status_xml           <U4 'None'
#     time_coverage_start  <U20 '2019-09-13T15:15:35Z'
#     time_coverage_end    <U20 '2019-09-13T15:19:03Z'
#     sweep_group_name     (sweep) <U8 'sweep_1' 'sweep_2' ... 'sweep_10'
#     sweep_fixed_angle    (sweep) float64 12.0 25.0 4.499 ... 5.499 1.5 2.499
# Attributes:
#     Conventions:          Cf/Radial
#     version:              H5rad 2.2
#     title:                None
#     institution:          WMO:10410,NOD:deess
#     references:           None
#     source:               None
#     history:              None
#     comment:              im/exported using wradlib
#     instrument_name:      None
#     site_name:            name of site where data were gathered
#     scan_name:            name of scan strategy used, if applicable
#     scan_id:              scan strategy id, if applicable. assumed 0 if missing
#     platform_is_mobile:   "true" or "false", assumed "false" if missing
#     ray_times_increase:   "true" or "false", assumed "true" if missing. This ...
#     field_names:          array of strings of field names present in this file.
#     time_coverage_start:  copy of time_coverage_start global variable
#     time_coverage_end:    copy of time_coverage_end global variable
#     simulated data:       "true" or "false", assumed "false" if missing. data...
#     instrument:           WMO:10410,NOD:deess

# %%
#vol.root = vol.root.assign(longitude=vol.root.longitude[0])
#vol.root = vol.root.assign(latitude=vol.root.latitude[0])
#vol.root = vol.root.assign(altitude=vol.root.altitude[0])

# %% [markdown]
# ## Export to OdimH5
#
# This exports the radar volume including all moments into one ODIM_H5 compliant data file.

# %%
vol.to_odim('testodim.h5')

# %% [markdown]
# ## Export to Cf/Radial2
#
# This exports the radar volume including all moments into one Cf/Radial2 compliant data file.

# %%
vol.to_cfradial2('testcfradial2.nc')

# %% [markdown]
# ## Import again and check equality
#
# Small time differences are possible so drop times before comparison

# %%
try:
    vol1 = OdimH5('testodim.h5', georef=True)
    vol2 = CfRadial('testcfradial2.nc', georef=True)
    xr.testing.assert_equal(vol1.root, vol2.root)
    xr.testing.assert_equal(vol1['sweep_1'].drop('time'), vol2['sweep_1'].drop('time'))
except:
    pass
